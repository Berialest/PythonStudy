# %%
import matplotlib.pyplot as plt 
import pandas as pd

# %%
stdata = pd.read_csv('c:\\data\\students.csv')      
stdata['Height'].plot(kind='hist',bins=6,title='Students Height Dstribution')

# %%
stdata['Height'].plot(kind='hist',bins=6,normed=True,title='Students Age Dstribution') 
stdata['Height'].plot(kind='kde',title='Students Height Dstribution', xlim=[155,185],
style = 'k--')   
plt.show()
# Out:
# C:\Window10\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
