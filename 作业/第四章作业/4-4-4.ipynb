# %%
import matplotlib.pyplot as plt 
import pandas as pd
import numpy as np

# %%
x = np.linspace(0,6.28,50)  
y=np.sin(x)                    
plt.plot(x,y, color='r')     
plt.plot(x,np.exp(-x),c='b') 
plt.show()
