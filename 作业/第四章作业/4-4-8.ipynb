# %%
import matplotlib.pyplot as plt 
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('c:\\data\\GDP.csv', index_col = 'Year')   
data.plot(title='GDP & Income',LineWidth=2,marker='o',linestyle='dashed', grid=True,use_index=True) #折线图
plt.show()
data.plot(logy=True,LineWidth=2,marker='o',linestyle='dashed',color='G') 
plt.show()
